# %% [markdown]
# # Práctica
#
# A continuación, se presentan ejercicios diseñados para aplicar los conocimientos adquiridos en sesiones anteriores del curso.
#
# ¡Es momento de ponerlos en práctica!

# %% [markdown]
# ### Ejercicio 1: importar datos desde Google Drive
#
# 1. Importa la biblioteca necesaria para acceder a archivos almacenados en Google Drive desde tu entorno de trabajo de Google Colab.
#
# 2. Asegúrate de tener una carpeta llamada `practica-1sem` en tu unidad de Google Drive y guarda en ella el archivo `tabla_gref_iter_pob_economic_act_nact_20_loc_p.csv`.

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 2: Cargar el archivo
#
# 1. Importa la biblioteca que te permita trabajar con **DataFrames**.
#
# 2. Lee el archivo `tabla_gref_iter_pob_economic_act_nact_20_loc_p.csv` que guardaste en la carpeta `practica-1sem` y guárdalo en un DataFrame llamado `df`.

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 3: Explorar el DataFrame
#
# 1. ¿Cuántas filas y columnas contiene el DataFrame `df`?
#
# 2. ¿Cuáles son los nombres de las columnas presentes en `df`?
#
# 3. ¿Existe alguna columna que contenga información geométrica (por ejemplo, coordenadas, geometrías, etc.)?

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 4: Tipo de datos de columnas
#
# 1. Identifica el tipo de dato de cada columna del DataFrame `df` o si no tienes una idea de cómo acceder a esta información, puedes probar con 5 columnas solamente.
#
# 2. ¿Hay columnas que no sean numéricas? En caso afirmativo, indica cuáles son y su tipo de dato.

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 5: Generar columna `geometry`
#
# 1. Importa la biblioteca adecuada para trabajar con datos espaciales (**geometrías.**)
#
# 2. A partir de las columnas `longitud` y `latitud`, crea una nueva columna llamada `geometry` que contenga objetos de tipo `Point`.
#
# 3. Asegúrate de que los puntos se creen correctamente usando una estructura de tipo _Simple Feature Geometry_.

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 6: Generar un nuevo objeto `GeoDataFrame`
#
# 1. Importa la biblioteca que te permita trabajar con **GeoDataFrames**.
#
# 2. Crea un nuevo objeto `GeoDataFrame` a partir del DataFrame `df`, asegurándote de que la columna `geometry` se utilice como la columna geométrica.

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 7: Filtrar columnas
#
# 1. Filtra el DataFrame para conservar únicamente las siguientes columnas: ``[nom_ent, nom_mun, nom_loc, tamloc, pobtot, pea, geometry]``

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 8: Filtrar valores de una columna
#
# 1. Filtra el ``GeoDataFrame`` para conservar únicamente los registros correspondientes a la entidad federativa de Jalisco.
#
# 2. ¿Cuántas filas y columnas tiene el ``GeoDataFrame`` resultante?

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 9: Visualiza el GeoDataFrame
#
# 1. Visualiza en un gráfico el contenido del ``GeoDataFrame`` de Jalisco que has filtrado previamente.
#
# 2. Personaliza la visualización ajustando parámetros como el color, transparencia (alpha), tamaño de los puntos u otros estilos.

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 10: CRS
#
# 1. Comprueba el sistema de referencia de coordenadas (CRS) del `GeoDataFrame` que has creado.
# 2. Indica el sistema de referencia de coordenadas (CRS) del `GeoDataFrame` que has creado en `EPSG:4623`

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 11: Genera un conteo de valores únicos
#
# 1. Realiza un conteo de los valores únicos en la columna  `tamloc` del GeoDataFrame filtrado.
#
# 2. Sustituye los valores numéricos de ``tamloc`` por etiquetas descriptivas utilizando un diccionario, por ejemplo:
#
# 1 --> 1-249 hab;
#
# 2 --> 250-499 hab; etc.
#
# ![](../source/images/tamloc.png)

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 12: Genera una agrupación con `pivot_table`
#
# 1. Crea una tabla dinámica utilizando`pivot_table` que muestre la suma de la población total (`pobtot`) agrupada por municipio (`nom_mun`) y localidad (`nom_loc`).
#
# 2. Identifica cuál es el municipio con mayor población total.
#
# 3. Identifica cuál es la localidad con mayor población total.

# %%
# Tu código aquí

# %%
# OJO --> convertir valors -999 en NaN
jal = jal.replace(-999, pd.NA)

# %% [markdown]
# ### Ejercicio 13:  Guardar el resultado en archivos
#
# 1. Guarda el ``GeoDataFrame`` filtrado en un archivo CSV.
#
# 2. Guarda el ``GeoDataFrame`` filtrado en un archivo SHP.
#
# 3. Ambos guardalos en una nueva carpeta llamada `resultados` dentro de la carpeta `practica-1sem`.

# %%
# Tu código aquí
